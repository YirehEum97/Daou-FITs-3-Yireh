# %% [markdown]
# # array

# %% [markdown]
# ## 실습 12

# %%
# 정수로 이루어진 배열 초기화
arr = [1,2,3,4,5]

# 특정 값으로 초기화
arr_zeros = [0]*5
arr_ones = [1]*5

arr = [10,20,30,40,50]
print(arr[0])
print(arr[2])
print(arr[-1])

arr = [1,2,3,4,5]
print(len(arr))
# Out:
# 10
# 30
# 50
# 5

# %% [markdown]
# ## 실습 13

# %%
# 배열 요소 추가, 삽입
arr = [1,2,3]
arr.append(4)
arr.insert(1,10)
arr_ones = [1]*5

# 배열 요소 삭제
arr = [10,20,30,40,50]
arr.remove(30)
arr.pop()
arr.pop(0)

# 배열 요소 수정
arr = [1,2,3,4,5]
arr[2] = 99

# 배열 합치기
arr1 = [1,2,3]
arr2 = [4,5,6]
arr3 = arr1 + arr2
arr1.extend(arr2)
